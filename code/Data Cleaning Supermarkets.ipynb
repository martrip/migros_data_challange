# %%
# %load_ext nb_black

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use("seaborn")

# %%
df_supermarkets = pd.read_csv(
    "/Users/lisach./Desktop/Github/migros_data_challange/data/supermarkets_raw_data.csv"
)
df_supermarkets
# Out:
#     business_status                                formatted_address  \
# 0       OPERATIONAL  Fraumünsterstrasse 16, 8001 Zürich, Switzerland
# 1       OPERATIONAL       Grubenstrasse 28, 8045 Zürich, Switzerland
# 2       OPERATIONAL   Förrlibuckstrasse 62, 8005 Zürich, Switzerland
# 3       OPERATIONAL          Ohmstrasse 11, 8050 Zürich, Switzerland
# 4       OPERATIONAL   Hofwiesenstrasse 350, 8050 Zürich, Switzerland
# ..              ...                                              ...
# 272     OPERATIONAL    Thurgauerstrasse 36, 8050 Zürich, Switzerland
# 273     OPERATIONAL   Dübendorfstrasse 447, 8051 Zürich, Switzerland
# 274     OPERATIONAL     Schwellistrasse 69, 8052 Zürich, Switzerland
# 275     OPERATIONAL      Zürcherstrasse 1, 8142 Uitikon, Switzerland
# 276     OPERATIONAL   Milchbuckstrasse 1/5, 8057 Zürich, Switzerland
#
#                                                   icon icon_background_color  \
# ...

# %%
df_supermarkets.columns
# Out:
# Index(['business_status', 'formatted_address', 'icon', 'icon_background_color',
#        'icon_mask_base_uri', 'name', 'photos', 'place_id', 'rating',
#        'reference', 'types', 'user_ratings_total', 'geometry.location.lat',
#        'geometry.location.lng', 'geometry.viewport.northeast.lat',
#        'geometry.viewport.northeast.lng', 'geometry.viewport.southwest.lat',
#        'geometry.viewport.southwest.lng', 'opening_hours.open_now',
#        'plus_code.compound_code', 'plus_code.global_code', 'supermarket_brand',
#        'permanently_closed', 'price_level'],
#       dtype='object')

# %%
# Drop columns
df_s = df_supermarkets.drop(
    columns=[
        "business_status",
        "icon",
        "icon_background_color",
        "icon_mask_base_uri",
        "photos",
        "place_id",
        "types",
        "user_ratings_total",
        "geometry.viewport.northeast.lat",
        "geometry.viewport.northeast.lng",
        "geometry.viewport.southwest.lat",
        "geometry.viewport.southwest.lng",
        "opening_hours.open_now",
        "plus_code.compound_code",
        "plus_code.global_code",
        "price_level",
        "permanently_closed",
        "reference",
    ],
    axis=1,
)
df_s
# Out:
#                                    formatted_address  \
# 0    Fraumünsterstrasse 16, 8001 Zürich, Switzerland
# 1         Grubenstrasse 28, 8045 Zürich, Switzerland
# 2     Förrlibuckstrasse 62, 8005 Zürich, Switzerland
# 3            Ohmstrasse 11, 8050 Zürich, Switzerland
# 4     Hofwiesenstrasse 350, 8050 Zürich, Switzerland
# ..                                               ...
# 272    Thurgauerstrasse 36, 8050 Zürich, Switzerland
# 273   Dübendorfstrasse 447, 8051 Zürich, Switzerland
# 274     Schwellistrasse 69, 8052 Zürich, Switzerland
# 275      Zürcherstrasse 1, 8142 Uitikon, Switzerland
# 276   Milchbuckstrasse 1/5, 8057 Zürich, Switzerland
#
#                                        name  rating  geometry.location.lat  \
# 0                          LIDL Switzerland     4.4              47.368770
# 1                              Lidl Schweiz     4.1              47.361769
# 2                              Lidl Schweiz     4.3              47.392481
# ...

# %%
df_s = df_s.rename(
    columns={
        "formatted_address": "address_shop",
        "name": "name_shop",
        "rating": "rating_shop",
        "geometry.location.lat": "lat_shop",
        "geometry.location.lng": "lng_shop",
    }
)
df_s
# Out:
#                                         address_shop  \
# 0    Fraumünsterstrasse 16, 8001 Zürich, Switzerland
# 1         Grubenstrasse 28, 8045 Zürich, Switzerland
# 2     Förrlibuckstrasse 62, 8005 Zürich, Switzerland
# 3            Ohmstrasse 11, 8050 Zürich, Switzerland
# 4     Hofwiesenstrasse 350, 8050 Zürich, Switzerland
# ..                                               ...
# 272    Thurgauerstrasse 36, 8050 Zürich, Switzerland
# 273   Dübendorfstrasse 447, 8051 Zürich, Switzerland
# 274     Schwellistrasse 69, 8052 Zürich, Switzerland
# 275      Zürcherstrasse 1, 8142 Uitikon, Switzerland
# 276   Milchbuckstrasse 1/5, 8057 Zürich, Switzerland
#
#                                   name_shop  rating_shop   lat_shop  lng_shop  \
# 0                          LIDL Switzerland          4.4  47.368770  8.541178
# 1                              Lidl Schweiz          4.1  47.361769  8.514720
# 2                              Lidl Schweiz          4.3  47.392481  8.515698
# ...

# %%
new = df_s["supermarket_brand"] = df_s["supermarket_brand"].str.split(
    ",", n=1, expand=True
)
df_s["supermarket_brand"] = new[0]
df_s
# Out:
#                                         address_shop  \
# 0    Fraumünsterstrasse 16, 8001 Zürich, Switzerland
# 1         Grubenstrasse 28, 8045 Zürich, Switzerland
# 2     Förrlibuckstrasse 62, 8005 Zürich, Switzerland
# 3            Ohmstrasse 11, 8050 Zürich, Switzerland
# 4     Hofwiesenstrasse 350, 8050 Zürich, Switzerland
# ..                                               ...
# 272    Thurgauerstrasse 36, 8050 Zürich, Switzerland
# 273   Dübendorfstrasse 447, 8051 Zürich, Switzerland
# 274     Schwellistrasse 69, 8052 Zürich, Switzerland
# 275      Zürcherstrasse 1, 8142 Uitikon, Switzerland
# 276   Milchbuckstrasse 1/5, 8057 Zürich, Switzerland
#
#                                   name_shop  rating_shop   lat_shop  lng_shop  \
# 0                          LIDL Switzerland          4.4  47.368770  8.541178
# 1                              Lidl Schweiz          4.1  47.361769  8.514720
# 2                              Lidl Schweiz          4.3  47.392481  8.515698
# ...

# %%
df_s.to_csv("companies_cleaned_data.csv", index=True)
